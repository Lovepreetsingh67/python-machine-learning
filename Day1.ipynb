# %%
name=(input("Enter the name:"))
Marks=float (input ("Enter the Marks:"))
if Marks>=45:
   print ("PASS")
else:
   print("FAIL")
# Out:
# Enter the name:Lovepreet Singh
# Enter the Marks:89
# PASS

# %%
my_var=100
print(f"Value:{my_var}, Type:{type(my_var)}")

my_var="Now I'm string"
print(f"Value:{my_var}, Type:{type(my_var)}")
# Out:
# Value:100, Type:<class 'int'>
# Value:Now I'm string, Type:<class 'str'>

# %%
a=5
print(f"Initial Value of a: {a}, Address: {id(a)}")
a=a+1
print(id(a))
# Out:
# Initial Value of a: 5, Address: 11645480
# 11645512

# %%
list_a=[10,20,30]
list_b=list_a   #both variables point to same list

list_b.append(40)
print(f"list_b:{list_b}")
print(f"list_a:{list_a}")

print(f"Are list_a and list_b same?{list_a is list_b}")
# Out:
# list_b:[10, 20, 30, 40]
# list_a:[10, 20, 30, 40]
# Are list_a and list_b same?True

# %%
list_a=[10,20,30]
list_c= list_a.copy()   #creates a shallow copy
list_c.append(50)
print(f"Modified List: {list_c}")
print(f"Original List: {list_a}")

print(f"Are list_a and _list_c same? {list_a is list_c}")
# Out:
# Modified List: [10, 20, 30, 50]
# Original List: [10, 20, 30]
# Are list_a and _list_c same? False

# %%
#Type casting/Conversion
num_int=20
num_float=5.5
result= num_int + num_float   #implicit conversion
print(f"Value: {result}, Type: {type(result)}")
# Out:
# Value: 25.5, Type: <class 'float'>

# %%
#Explicit conversion
str_num="123"
casted_num=int(str_num)

print(f"Value: {casted_int}, Type:{type(casted_int)}")
# Out:
# Value: 123, Type:<class 'int'>

# %%
#converting list into set to remove duplicates

number_list= [1,2,2,3,4,5,5,6]
unique_numbers=set(number_list)
print(f"Original list: {number_list}")
print(f"Unique set: {unique_numbers}")
# Out:
# Original list: [1, 2, 2, 3, 4, 5, 5, 6]
# Unique set: {1, 2, 3, 4, 5, 6}

# %%
#tuple into list
fruits= ("apple","cherry","orange")

l_fruits=list(fruits)
l_fruits[1]="banana"
fruits= tuple(l_fruits)
print(fruits)
# Out:
# ('apple', 'banana', 'orange')

# %%
#Dictionary

hyperparameters={
    "learning_rate":0.001,
    "batch_size":32,
    "optimizer":"Adam",
    "epochs":10,
    "early_stopping":True
}
print("Learning rate:",hyperparameters["learning_rate"])
print("Batch size:",hyperparameters["batch_size"])
print("Optimizer:",hyperparameters["optimizer"])
print("Epochs:",hyperparameters["epochs"])
print("Early stopping:",hyperparameters["early_stopping"])

#updating
hyperparameters["learning_rate"]=0.005
print("\nUpdated Hyperparameters:",hyperparameters)
# Out:
# Learning rate: 0.001
# Batch size: 32
# Optimizer: Adam
# Epochs: 10
# Early stopping: True
#
# Updated Hyperparameters: {'learning_rate': 0.005, 'batch_size': 32, 'optimizer': 'Adam', 'epochs': 10, 'early_stopping': True}

# %%
roles=["admin","user","user","editor","admin","user","viewer"]
print("Total user accounts:",len(roles))

unique_roles=set(roles)
print("Unique roles:",unique_roles)

print("Count of unique roles:", len(unique_roles))
# Out:
# Total user accounts: 7
# Unique roles: {'admin', 'editor', 'viewer', 'user'}
# Count of unique roles: 4

# %%
#Check prime numbers
number_to_check=7
is_prime=True

if number_to_check<=1:
  is_prime=False
else:
  for i in range(2,int(number_to_check**0.5)+1):
    if number_to_check%i==0:
      is_prime=False
      break

if is_prime:
  print(f"{number_to_check} is a prime number.")
else:
  print(f"{number_to_check} is not a prime number.")
# Out:
# 7 is a prime number.

# %%
#prime number
num=int(input("Enter a number:"))

if num<=1:
  print(f"{num} is not a prime number.")
else:
  for i in range(2,int(num**0.5)+1):
    if num%i==0:
      print(f"{num} is not a prime number")
      break
  else:
    print(f"{num} is a prime number")
# Out:
# Enter a number:34
# 34 is not a prime number

# %%
name=input("Enter student name:")
marks=float(input("Enter marks obtained:"))

if marks>=30:
  status="Pass"
else:
  status="Fail"

print("\n"+"="*30)
print("        Result Card   ")
print("="*30)
print(f"Student Name: {name}")
print(f"Marks Obtained: {marks}/100")
print(f"Status: {status}")
print("="*30)
# Out:
# Enter student name:Lovepreet Singh
# Enter marks obtained:87
#
# ...
#         Result Card
# ...
# Student Name: Lovepreet Singh
# Marks Obtained: 87.0/100
# Status: Pass
# ...

# %%
x=42
y=x
print(f"id(x):{id(x)}")
print(f"id(y):{id(y)}")
# Out:
# id(x):11646664
# id(y):11646664

# %%
my_int=-10
my_float=5.345
my_complex=2+3j

print(f"Int:{my_int} ({type(my_int)})")
print(f"Float:{my_float} ({type(my_float)})")
print(f"Complex:{my_complex.real} , Imaginary part:{my_complex.imag}")
#
# Out:
# Int:-10 (<class 'int'>)
# Float:5.345 (<class 'float'>)
# Complex:2.0 , Imaginary part:3.0

# %%
a=[1,2,3]
b=a
c=[1,2,3]

print(a is b)
print(a==c)
print(a is c)
# Out:
# True
# True
# False
